# %% [markdown]
# # Transfer Markt Scraping - Summer Transfers 19/20
#
# Explicar isto

# %% [markdown]
# ## Import libraries

# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd

# %% [markdown]
# ## Scraping function definition
#
# - Input: numbers of pages to scrap (default = 1)
# - Output: list of transfers

# %%
def Scraping_TransferMarkt_SummerTransfers(number_pages):
    
    data = []
    headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}
    url = 'https://www.transfermarkt.com/transfers/sommertransfers/statistik?ajax=yw1&altersklasse=&ausrichtung=&land_id=0&leihe=&plus=1&sort=abloese.desc&spielerposition_id='

    for page in list(range(1, pages + 1)):

        page = url + '&page=' + str(page)
        tree = requests.get(page, headers = headers)
        soup = BeautifulSoup(tree.content, 'html.parser')
        table = soup.find('table', attrs = {'class':'items'})
        table_body = table.find('tbody')
        rows = table_body.findAll('tr')

        for row in rows[::7]:
            
            cols = row.findAll('td')
            cols = [ele.text.strip() for ele in cols]
            links = row.find_all('a', href = True)
            links = [ele['href'].split('/')[-1] for ele in links]
            countries = row.find_all('img', alt = True)[-4:]
            countries = [ele['alt'] for ele in countries]
            joinedlist = cols + links + countries
            data.append([ele for ele in joinedlist if ele]) # Get rid of empty values
        
        time.sleep(.5)
    
    return data

# %% [markdown]
# ## Execute scraping function and export raw data to CSV file

# %%
df = pd.DataFrame(Scraping_TransferMarkt_SummerTransfers(324))
df.to_csv('Preprocessed_Transfers.csv', index = False)

# %% [markdown]
# ## Import scraped data

# %%
df = pd.read_csv('Preprocessed_Transfers.csv')
df.head(n = 2)
# Out:
#    0                                       1                  2  \
# 0  1         João Félix \n\n\nSecond Striker         João Félix
# 1  2  Antoine Griezmann \n\n\nCentre-Forward  Antoine Griezmann
#
#                 3   4              5                                6  \
# 0  Second Striker  19   70,00 mil. €        Benfica \n\n\n\n Liga NOS
# 1  Centre-Forward  28  130,00 mil. €  Atlético Madrid \n\n\n\n LaLiga
#
#                  7         8                                9  ...   14   15  \
# 0          Benfica  Liga NOS  Atlético Madrid \n\n\n\n LaLiga  ...  294  294
# 1  Atlético Madrid    LaLiga     FC Barcelona \n\n\n\n LaLiga  ...   13   13
#
#     16   17   18   19               20        21               22     23
# 0  PO1   13   13  ES1       SL Benfica  Portugal  Atlético Madrid  Spain
# 1  ES1  131  131  ES1  Atlético Madrid     Spain     FC Barcelona  Spain
#
# [2 rows x 24 columns]

# %%
df.drop(df.columns[[1,6,9,15,18]], axis = 1, inplace = True)
df.head(n = 2)
# Out:
#    0                  2               3   4              5                7  \
# 0  1         João Félix  Second Striker  19   70,00 mil. €          Benfica
# 1  2  Antoine Griezmann  Centre-Forward  28  130,00 mil. €  Atlético Madrid
#
#           8               10      11             12      13   14   16   17  \
# 0  Liga NOS  Atlético Madrid  LaLiga  126,00 mil. €  462250  294  PO1   13
# 1    LaLiga     FC Barcelona  LaLiga  120,00 mil. €  125781   13  ES1  131
#
#     19               20        21               22     23
# 0  ES1       SL Benfica  Portugal  Atlético Madrid  Spain
# 1  ES1  Atlético Madrid     Spain     FC Barcelona  Spain

# %% [markdown]
# ## Define column names

# %%
df.columns = ['ID', 'Player', 'Position', 'Age', 'MarketValue',
              'TeamLeft', 'LeagueLeft', 'TeamJoined', 'LeagueJoined', 'TransferFee', 
              'PlayerID', 'TeamLeftID', 'LeagueLeftID', 'TeamJoinedID', 'LeagueJoinedID',
              'TeamLeft2', 'CountryLeft', 'TeamJoined2', 'CountryJoined']
df.head(n = 2)
# Out:
#    ID             Player        Position  Age    MarketValue         TeamLeft  \
# 0   1         João Félix  Second Striker   19   70,00 mil. €          Benfica
# 1   2  Antoine Griezmann  Centre-Forward   28  130,00 mil. €  Atlético Madrid
#
#   LeagueLeft       TeamJoined LeagueJoined    TransferFee  PlayerID  \
# 0   Liga NOS  Atlético Madrid       LaLiga  126,00 mil. €    462250
# 1     LaLiga     FC Barcelona       LaLiga  120,00 mil. €    125781
#
#    TeamLeftID LeagueLeftID TeamJoinedID LeagueJoinedID        TeamLeft2  \
# 0         294          PO1           13            ES1       SL Benfica
# 1          13          ES1          131            ES1  Atlético Madrid
#
#   CountryLeft      TeamJoined2 CountryJoined
# 0    Portugal  Atlético Madrid         Spain
# 1       Spain     FC Barcelona         Spain

# %%
df.to_csv('Precleaned_Transfers.csv', index = False)

# %% [markdown]
# ## Data cleaning

# %%
#df = pd.read_csv('Precleaned_Transfers.csv')

# %% [markdown]
# - Remove loans

# %%
df = df.loc[~df['TransferFee'].str.startswith('Loan', na = False)]

# %% [markdown]
# - Remove invalid and unknown transfer fees

# %%
df = df.loc[~df['TransferFee'].str.startswith('draft', na = False)]
df = df.loc[~df['TransferFee'].str.startswith('?', na = False)]
df = df.loc[~df['TransferFee'].str.startswith('-', na = False)]

# %% [markdown]
# ### Function definition: Conversion from string monetary to floating number

# %%
def currency_string_to_number(value):
   
    multiplier = 1
    number_delimiter_position = value.find(' ')
    y = value.replace(',','.')
     
    if value == 'Free transfer':
        return 0.0
    elif value[-6:] == 'mil. €':
        multiplier = 1000000
        return float(y[:number_delimiter_position])*multiplier
    elif value[-10:] == 'thousand €':
        multiplier = 1000
        return float(y[:number_delimiter_position])*multiplier
    elif value[-3:] == 'K €':
        multiplier = 1000
        return float(y[:number_delimiter_position])*multiplier
    elif value == '-':
        return 0.0
    else:
        return(float(value))

# %% [markdown]
# - Apply conversion function to Transfer Fees

# %%
df['TransferFee'] = df['TransferFee'].apply(currency_string_to_number)

# %% [markdown]
# - Remove invalid market value entries

# %%
df = df[df['MarketValue'] != 'Loros \n\n\n\n Ascenso MX Apertura']

# %% [markdown]
# - Apply conversion function to Market Value

# %%
df['MarketValue'] = df['MarketValue'].apply(currency_string_to_number)

# %%
# Ligas do FIFA !!!
FIFA_leagues = ['A1','AR1N','AUS1','BE1','BRA1','C1','C2','DK1',
                'ES1','ES2','FI1','FR1','FR2','GB1','GB2','GB3',
                'GB4','GR1','IT1','IT2','JAP1','KR1','L1','L2','L3',
                'MEXA','MLS1','NL1','NO1','PL1','PO1','RO1','RU1',
                'SC1','SE1','SFA1','TR1','TS1','UAE1']

# %%
df = df.loc[ (df['LeagueLeftID'].isin(FIFA_leagues)) & (df['LeagueJoinedID'].isin(FIFA_leagues)), : ]

# %%
df.Position.value_counts()
# Out:
# Centre-Back           239
# Centre-Forward        203
# Central Midfield      145
# Right-Back            106
# Left Winger            94
# Defensive Midfield     92
# Left-Back              90
# Goalkeeper             88
# Right Winger           84
# Attacking Midfield     74
# Left Midfield          23
# Right Midfield         19
# Second Striker         14
# Name: Position, dtype: int64

# %%
df.LeagueJoinedID.value_counts()
# Out:
# IT1     113
# ES1      95
# FR1      93
# L1       85
# GB1      79
# L2       74
# GB2      73
# RU1      53
# TR1      50
# BE1      48
# FR2      46
# RO1      32
# GR1      31
# NL1      30
# PO1      29
# PL1      29
# L3       29
# AUS1     27
# ES2      26
# DK1      25
# SC1      24
# AR1N     24
# C1       20
# IT2      19
# A1       15
# MEXA     14
# GB3      13
# TS1      12
# BRA1     11
# KR1      10
# UAE1      9
# GB4       9
# C2        8
# MLS1      6
# SFA1      5
# JAP1      4
# SE1       1
# Name: LeagueJoinedID, dtype: int64

# %%
df = df[df['Position'] != 'Defender']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1288 entries, 0 to 2488
# Data columns (total 19 columns):
# ID                1288 non-null int64
# Player            1288 non-null object
# Position          1288 non-null object
# Age               1288 non-null int64
# MarketValue       1288 non-null float64
# TeamLeft          1288 non-null object
# LeagueLeft        1288 non-null object
# TeamJoined        1288 non-null object
# LeagueJoined      1288 non-null object
# TransferFee       1288 non-null float64
# PlayerID          1288 non-null int64
# TeamLeftID        1288 non-null int64
# LeagueLeftID      1288 non-null object
# TeamJoinedID      1288 non-null object
# LeagueJoinedID    1288 non-null object
# TeamLeft2         1288 non-null object
# CountryLeft       1288 non-null object
# TeamJoined2       1288 non-null object
# CountryJoined     1288 non-null object
# dtypes: float64(2), int64(4), object(13)
# memory usage: 201.2+ KB

# %% [markdown]
# ## Drop duplicates Player entries but keep the latest transfer

# %%
df = df.drop_duplicates(subset = 'PlayerID', keep = 'first')

# %%
df.groupby('PlayerID').filter(lambda x: len(x) > 1)
# Out:
# Empty DataFrame
# Columns: [ID, Player, Position, Age, MarketValue, TeamLeft, LeagueLeft, TeamJoined, LeagueJoined, TransferFee, PlayerID, TeamLeftID, LeagueLeftID, TeamJoinedID, LeagueJoinedID, TeamLeft2, CountryLeft, TeamJoined2, CountryJoined]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1271 entries, 0 to 2488
# Data columns (total 19 columns):
# ID                1271 non-null int64
# Player            1271 non-null object
# Position          1271 non-null object
# Age               1271 non-null int64
# MarketValue       1271 non-null float64
# TeamLeft          1271 non-null object
# LeagueLeft        1271 non-null object
# TeamJoined        1271 non-null object
# LeagueJoined      1271 non-null object
# TransferFee       1271 non-null float64
# PlayerID          1271 non-null int64
# TeamLeftID        1271 non-null int64
# LeagueLeftID      1271 non-null object
# TeamJoinedID      1271 non-null object
# LeagueJoinedID    1271 non-null object
# TeamLeft2         1271 non-null object
# CountryLeft       1271 non-null object
# TeamJoined2       1271 non-null object
# CountryJoined     1271 non-null object
# dtypes: float64(2), int64(4), object(13)
# memory usage:
# 2443  Bidvest Wits FC    ABSA Premiership  Orlando Pirates
# 2446      Rubin Kazan        Premier Liga     Arsenal Tula
# 2447    Royal Antwerp  Jupiler Pro League       Ajman Club
# 2448   Genclerbirligi           Süper Lig        Konyaspor
# 2454      G. Bordeaux             Ligue 1  Valenciennes FC
# 2456       Villarreal              LaLiga   Sporting Gijón
# 2461            Dijon             Ligue 1           Troyes
# 2462        Rotherham          League One       Portsmouth
# 2464           Chivas    Liga MX Apertura     Querétaro FC
# 2465     ADO Den Haag          Eredivisie     Union Berlin
# 2474       US Orléans             Ligue 2         Albacete
# 2479   Vit. Guimarães            Liga NOS      Santa Clara
# 2482    Oxford United          League One          Cardiff
# 2484         Charlton        Championship          Rangers
# 2487     Bristol City        Championship         Millwall
# 2488         Orenburg        Premier Liga              Ufa
#
#             LeagueJoined  TransferFee  PlayerID  TeamLeftID LeagueLeftID  \
# 0                 LaLiga  126000000.0    462250         294          PO1
# 1                 LaLiga  120000000.0    125781          13          ES1
# 2                 LaLiga  100000000.0     50202         631          GB1
# 3         Premier League   87000000.0    177907        1003          GB1
# 4                Serie A   85500000.0    326031         610          NL1
# 5             Bundesliga   80000000.0    281963          13          ES1
# 6         Premier League   80000000.0    343052        1082          FR1
# 7                 LaLiga   75000000.0    326330         610          NL1
# 8         Premier League   70000000.0    357565          13          ES1
# 9         Premier League   65000000.0    182712         506          IT1
# 10               Serie A   65000000.0     96341         985          GB1
# 11                LaLiga   60000000.0    257462          24           L1
# 12        Premier League   60000000.0    450936        1041          FR1
# 13        Premier League   55000000.0    477758         873          GB1
# 14                LaLiga   50000000.0    401530         720          PO1
# 15                LaLiga   48000000.0    291417        1041          FR1
# 16                LaLiga   45000000.0    412363         221         BRA1
# 17        Premier League   45000000.0     51471         418          ES1
# 18        Premier League   45000000.0    249565         162          FR1
# 19        Premier League   44000000.0    333241         533           L1
# 20        Premier League   40000000.0    181375          24           L1
# 21          Premier Liga   40000000.0    323704         131          ES1
# 22               Ligue 1   40000000.0    146854         368          ES1
# 23        Premier League   38000000.0    206040         294          PO1
# 24               Serie A   38000000.0    316889         383          NL1
# 25               Serie A   37000000.0    145707         281          GB1
# 26               Serie A   36000000.0    104752          12          IT1
# 27            Bundesliga   35000000.0    353366          79           L2
# 28                LaLiga   35000000.0    146227         131          ES1
# 29        Premier League   33400000.0    246968         762          GB1
# ...                  ...          ...       ...         ...          ...
# 2388  Jupiler Pro League          0.0    227534        3329          PO1
# 2393         Superligaen          0.0     89541        3551           A1
# 2396            A-League          0.0    485449        7831         AUS1
# 2402           Süper Lig          0.0    203764         618          FR1
# 2409             Ligue 1          0.0    282900         667          FR1
# 2415             3. Liga          0.0    150080          52           L3
# 2417        Championship          0.0    121254         349          GB2
# 2418        Championship          0.0    128902        1039          GB2
# 2419        Championship          0.0    134424        1071          GB2
# 2420        Championship          0.0    208428        1028          GB2
# 2429            A-League          0.0    385918        1132          GB1
# 2430            A-League          0.0    399165        7831         AUS1
# 2431            Liga NOS          0.0     72855        2457          PO1
# 2440            A-League          0.0    110023         970         AUS1
# 2443    ABSA Premiership          0.0    242021       10680         SFA1
# 2446        Premier Liga          0.0    260681        2698          RU1
# 2447     UAE Gulf League          0.0     45347        1096          BE1
# 2448           Süper Lig          0.0     55524         820          TR1
# 2454             Ligue 2          0.0    238720          40          FR1
# 2456             LaLiga2          0.0     56134        1050          ES1
# 2461             Ligue 2          0.0    452876        2969          FR1
# 2462          League One          0.0    192239        1194          GB3
# 2464    Liga MX Apertura          0.0     67192        6711         MEXA
# 2465          Bundesliga          0.0    188888        1268          NL1
# 2474             LaLiga2          0.0    203498       10868          FR2
# 2479            Liga NOS          0.0    211107        2420          PO1
# 2482        Championship          0.0    148299         988          GB3
# 2484         Premiership          0.0    468198         358          GB2
# 2487        Championship          0.0     57070         698          GB2
# 2488        Premier Liga          0.0    186279       14589          RU1
#
#      TeamJoinedID LeagueJoinedID              TeamLeft2   CountryLeft  \
# 0              13            ES1             SL Benfica      Portugal
# 1             131            ES1        Atlético Madrid         Spain
# 2             418            ES1             Chelsea FC       England
# 3             985            GB1         Leicester City       England
# 4             506            IT1         Ajax Amsterdam   Netherlands
# 5              27             L1        Atlético Madrid         Spain
# 6              11            GB1             LOSC Lille        France
# 7             131            ES1         Ajax Amsterdam   Netherlands
# 8             281            GB1        Atlético Madrid         Spain
# 9             281            GB1            Juventus FC         Italy
# 10             46            IT1      Manchester United       England
# 11            418            ES1    Eintracht Frankfurt       Germany
# 12            148            GB1         Olympique Lyon        France
# 13            985            GB1         Crystal Palace       England
# 14            418            ES1               FC Porto      Portugal
# 15            418            ES1         Olympique Lyon        France
# 16            418            ES1              Santos FC        Brazil
# 17            631            GB1            Real Madrid         Spain
# 18           1003            GB1              AS Monaco        Monaco
# 19            762            GB1    TSG 1899 Hoffenheim       Germany
# 20            379            GB1    Eintracht Frankfurt       Germany
# 21            964            RU1           FC Barcelona         Spain
# 22            162            FR1             Sevilla FC         Spain
# 23            543            GB1             SL Benfica      Portugal
# 24           6195            IT1          PSV Eindhoven   Netherlands
# 25            506            IT1        Manchester City       England
# 26           6195            IT1                AS Roma         Italy
# 27             27             L1          VfB Stuttgart       Germany
# 28           1049            ES1           FC Barcelona         Spain
# 29           1003            GB1       Newcastle United       England
# ...           ...            ...                    ...           ...
# 2388        29228            BE1           FC Famalicão      Portugal
# 2393         5724            DK1    SC Rheindorf Altach       Austria
# 2396          970           AUS1          Brisbane Roar     Australia
# 2402          820            TR1       AS Saint-Étienne        France
# 2409         1160            FR1   RC Strasbourg Alsace        France
# 2415         1622             L3           MSV Duisburg       Germany
# 2417          512            GB2            Barnsley FC       England
# 2418          512            GB2    Queens Park Rangers       England
# 2419          512            GB2         Wigan Athletic       England
# 2420          512            GB2            Millwall FC       England
# 2429         7831           AUS1             Burnley FC       England
# 2430          970           AUS1          Brisbane Roar     Australia
# 2431         1075            PO1         Belenenses SAD      Portugal
